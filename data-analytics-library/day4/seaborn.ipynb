# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
flights = sns.load_dataset('flights')

# %%
flights
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
plt.figure(figsize=(10,6))

sns.lineplot(x='year',y='passengers',data=flights)

plt.title('passengers over time')
plt.xlabel('year')
plt.ylabel('passengers')
# Out:
# Text(0, 0.5, 'passengers')

# %%
tips = sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
plt.figure(figsize=(8,6))

sns.scatterplot(x='total_bill',y='tip',data=tips,hue='time',palette='Set1')

plt.title('Total Bill vs Tip')
plt.xlabel('Total Bill')
plt.ylabel('Tip')
# Out:
# Text(0, 0.5, 'Tip')

# %%
plt.figure(figsize=(8,6))

sns.barplot(x='day',y='total_bill',errorbar=None,data=tips,hue='sex',palette='Set1')

plt.title('Average Total Bill by Day')
plt.xlabel('day')
plt.ylabel('Average Total Bill ')
# Out:
# Text(0, 0.5, 'Average Total Bill ')

# %%
titanic=sns.load_dataset('titanic')
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sns.countplot(x='pclass',data=titanic,hue='survived')
# Out:
# <Axes: xlabel='pclass', ylabel='count'>

# %%
sns.countplot(x='class',data=titanic,hue='survived',palette='Set1')
# Out:
# <Axes: xlabel='class', ylabel='count'>

# %%
sns.countplot(y='pclass',data=titanic,hue='survived',palette='Set1')
# Out:
# <Axes: xlabel='count', ylabel='pclass'>

# %%
sns.countplot(y='pclass',data=titanic,hue='survived',palette='Set1')
plt.legend(fancybox=True, facecolor='c', shadow=True)

# %%
plt.figure(figsize=(8,6))

sns.histplot(x=tips['total_bill'],bins=10)

plt.title('dist of Total Bill')
plt.xlabel('total bill')
plt.ylabel('frequency')
plt.show()

# %%
iris=sns.load_dataset('iris')
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.pairplot(iris)

# %%
sns.pairplot(iris,hue='species')

# %%
sns.pairplot(iris,hue='species',diag_kind='hist')

# %%
#sns.pairplot(iris,hue='species' , x_vars=['sepal_width','petal_width'] ,y_vars=['sepal_width','petal_width'])
sns.pairplot(iris,hue='species' , vars=['sepal_width','petal_width'])

# %%
flights
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
new_flights= flights.pivot(index='month',columns='year', values='passengers')
new_flights
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# ...

# %%
sns.heatmap(new_flights)
# Out:
# <Axes: xlabel='year', ylabel='month'>

# %%
sns.heatmap(new_flights,annot=True)
# Out:
# <Axes: xlabel='year', ylabel='month'>

# %%
sns.heatmap(new_flights,annot=True,fmt='d')
# Out:
# <Axes: xlabel='year', ylabel='month'>

# %%
sns.heatmap(new_flights,annot=True,fmt='d',cmap='crest')
# Out:
# <Axes: xlabel='year', ylabel='month'>

# %%
iris_corr=iris.corr(numeric_only=True)
iris_corr
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
sns.heatmap(iris_corr,annot=True,cmap='GnBu')
# Out:
# <Axes: >
